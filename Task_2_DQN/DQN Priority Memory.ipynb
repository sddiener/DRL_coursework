# %%
import gym
import numpy as np
import random
import time 
import matplotlib.pyplot as plt
from collections import namedtuple

import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# plotting
# %matplotlib inline
import time
import pylab as pl
from IPython import display

# %%
env = gym.make("LunarLander-v2")
print(env.action_space) #[Output: ] Discrete(2)
print(env.observation_space) # [Output: ] Box(4,)
# Out:
# Discrete(4)
# Box([-inf -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf], (8,), float32)

# %% [markdown]
# # Exercise 1 - Replay Buffer for Experience replay
#
# The first step of this lab is to create a Replay Buffer that will allow us to use Experience Replay and mini-batch learning.
# - First, we create a class Transition using named tuple, which holds state transition in a dedicated data structure.
# - Then, create a Replay Memory class that collects transition in a First In First Out fashion (fixed memory size). This Replay memory should convert the states, action, rewards into tensors.
#
# The models presented in the Pytorch tutorial are quite generic and can be used as is.

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))
Data = namedtuple('Data', ("priority", "probability", "weight","index"))

# %%
class ReplayMemory:

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.data = []
        self.position = 0

    def save_transition(self, state, action, next_state, reward):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        
        state_tensor = T.from_numpy(state)
        
        if next_state is None:
            state_tensor_next = None            
        else:
            state_tensor_next = T.from_numpy(next_state)
        
        action_tensor = T.tensor([action], device=device).unsqueeze(0)

        reward = T.tensor([reward], device=device).unsqueeze(0)/10. # reward scaling

        self.memory[self.position] = Transition(state_tensor, action_tensor, state_tensor_next, reward)  # save the transition
        self.memory[self.position] = Transition(state_tensor, action_tensor, state_tensor_next, reward)  # save prio data

        
        self.position = (self.position + 1) % self.capacity  # loop around memory

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# # Exercise 2: Q-network
#
# A Q-network is a neural network that maps states to Q-values for each actions.
#
# Implement a first version of Q-networks.
# Keep it simple (e.g. 3 hidden layers, with Relu activations).

# %%
# if gpu is to be used
device = T.device("cuda" if T.cuda.is_available() else "cpu")

class DQN(nn.Module):

    def __init__(self, input_size, size_hidden, output_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, size_hidden)
        self.fc2 = nn.Linear(size_hidden, size_hidden)   
        self.fc3 = nn.Linear(size_hidden, size_hidden)  
        self.fc4 = nn.Linear(size_hidden, output_size)
        
        
    def forward(self, x):
        h1 = F.relu(self.fc1(x.float()))  # self.bn1()
        h2 = F.relu(self.fc2(h1))  # self.bn2()
        h3 = F.relu(self.fc3(h2))  # self.bn3()
        output = self.fc4(h3) # .view(h3.size(0), -1)
        return output

# %% [markdown]
# # Exercise 3 - Set up the Q-networks
#
# In DQN, the weights of the target network are copied from the weights of policy network every few iterations.
#
# We set the frequency of update using TARGET_UPDATE = 10.
#
# Instead of RMSprop we will use SGD.

# %%
OBS_SIZE = 8
HIDDEN_SIZE = 64
ACTION_SIZE = 4

Q_network = DQN(OBS_SIZE, HIDDEN_SIZE, ACTION_SIZE).to(device)
Q_target = DQN(OBS_SIZE, HIDDEN_SIZE, ACTION_SIZE).to(device)
Q_target.load_state_dict(Q_network.state_dict())
Q_target.eval()

TARGET_UPDATE = 20

optimizer = optim.Adam(Q_network.parameters(), lr=0.001)
memory = ReplayMemory(500000)

# %% [markdown]
# # Exercise 4 - Epsilon-greedy policy
#
# You can take inspiration from pytorch tutorial and implement the select_action function.
# Or, alternatively, you can implement a E-greedy policy class that will select epsilon greedy actions..

# %%
class E_Greedy_Policy():
    
    def __init__(self, epsilon, decay, min_epsilon):
        
        self.epsilon = epsilon
        self.epsilon_start = epsilon
        self.decay = decay
        self.epsilon_min = min_epsilon
                
    def __call__(self, state):
                
        is_greedy = random.random() > self.epsilon
        if is_greedy :
            # we select greedy action
            with T.no_grad():
                Q_network.eval()
                index_action = Q_network(state).argmax().detach().cpu().numpy().item()  # state is on cpu instead of GPU!
                Q_network.train()

        else:
            # we sample a random action
            index_action = env.action_space.sample() # select random action (4 possible values)
        
        return index_action
                
    def update_epsilon(self):
        
        self.epsilon = self.epsilon*self.decay
        if self.epsilon < self.epsilon_min:
            self.epsilon = self.epsilon_min
        
    def reset(self):
        self.epsilon = self.epsilon_start

# %% [markdown]
# # Exercise 5 - Training loop

# %%
policy = E_Greedy_Policy(epsilon=0.5, decay=0.997, min_epsilon=0.001)
BATCH_SIZE = 64
GAMMA = 0.99

def optimize_model():
    
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    non_final_mask = T.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device=device, dtype=T.bool)
    non_final_next_states = T.cat([s for s in batch.next_state if s is not None])
    non_final_next_states = T.reshape(non_final_next_states, (non_final_mask.sum(), -1)).float().to(device)  # Reshape to (nr. non final, 8)

    state_batch = T.cat(batch.state).float().to(device)  # .float().to(device) to move to GPU
    state_batch = T.reshape(state_batch, (BATCH_SIZE, -1))  # Reshape to (batch_size, 8)
    action_batch = T.cat(batch.action).to(device)
    reward_batch = T.cat(batch.reward).float().to(device)
    
    # Compute Q values using policy net
    Q_values = Q_network(state_batch).gather(1, action_batch)

    # Compute next Q values using Q_targets
    next_Q_values = T.zeros( BATCH_SIZE, device=device).to(device)
    next_Q_values[non_final_mask] = Q_target(non_final_next_states).max(1)[0].detach()
    next_Q_values = next_Q_values.unsqueeze(1)
    
    # Compute targets
    target_Q_values = (next_Q_values * GAMMA) + reward_batch
    
    # Compute MSE Loss
    loss = F.mse_loss(Q_values, target_Q_values)
    
    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    
    # Trick: gradient clipping
    for param in Q_network.parameters():
        param.grad.data.clamp_(-1, 1)
        
    optimizer.step()
    
    return loss

# %%
env = gym.make("LunarLander-v2")  # create environment

num_episodes = 2000
policy.reset()
rewards_history = []

# Warmup phase!
memory_filled = False
print("Warmup phase...")
while not memory_filled:
    
    state = env.reset()  # 8 states: coordinates of the lander (x,y), linear velocities (x,y), angle, angular velocity, 2 bools if each leg is touches ground.
    done = False
    total_reward = 0
    
    while not done:  # for each episode
        # Get action and act in the world
        state_tensor = T.from_numpy(state).float().to(device)
        action = policy(state_tensor)  # <<--- choose greedy (choose index of highest q-value predicted by network) or exploration
        next_state, reward, done, __ = env.step(action)
        total_reward += float(reward)
        
        # Observe new state
        if done:
            next_state = None

        # Store the transition in memory
        memory.save_transition(state, action, next_state, float(reward))
        state = next_state

    memory_filled = memory.capacity == len(memory)

print('Done with the warmup')
    
for i_episode in range(num_episodes):
    # New dungeon at every run
    state = env.reset()
    done = False
    total_reward = 0
    
    
    while not done:  # iterate through states
        
        # Get action and act in the world
        state_tensor = T.from_numpy(state).float().to(device)  # <<--- convert state to tensor and move to GPU
        
        action = policy(state_tensor)   # choose greedy (index of q-value predictions) or exploration
        next_state, reward, done, __ = env.step(action)
        total_reward += float(reward)
        
        # Observe new state
        if done:
            next_state = None
        memory.save_transition(state, action, next_state, float(reward))  # Store the transition in memory
        state = next_state  # Move to the next state

        # Perform one step of the optimization
        #started_training = True
        loss = optimize_model()

    policy.update_epsilon()
    rewards_history.append( float(total_reward) )

    
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        Q_target.load_state_dict(Q_network.state_dict())
    
    if i_episode % 10 == 0:
        avg_rewards_10 = sum(rewards_history[-10:])/10

        print('Episode {} - reward: {:.3f}, avg. reward (past 10 ep.): {:.3f}, eps: {:.3f} loss: {:.3f} '.format(
            i_episode, total_reward, avg_rewards_10, policy.epsilon, loss))   
    
print('Complete')
# Out:
# Warmup phase...
# Done with the warmup
# Episode 0 - reward: -112.210, avg. reward (past 10 ep.): -11.221, eps: 0.498 loss: 1.664
# Episode 10 - reward: -138.086, avg. reward (past 10 ep.): -252.405, eps: 0.484 loss: 0.018
# Episode 20 - reward: -226.287, avg. reward (past 10 ep.): -166.761, eps: 0.469 loss: 0.328
# Episode 30 - reward: -100.653, avg. reward (past 10 ep.): -129.794, eps: 0.456 loss: 0.118
# Episode 40 - reward: -181.886, avg. reward (past 10 ep.): -161.342, eps: 0.442 loss: 0.089
# Episode 50 - reward: -94.655, avg. reward (past 10 ep.): -174.407, eps: 0.429 loss: 0.028
# Episode 60 - reward: -6.712, avg. reward (past 10 ep.): -128.209, eps: 0.416 loss: 0.380
# Episode 70 - reward: -294.605, avg. reward (past 10 ep.): -117.669, eps: 0.404 loss: 0.214
# Episode 80 - reward: 0.418, avg. reward (past 10 ep.): -49.099, eps: 0.392 loss: 0.105
# Episode 90 - reward: -84.251, avg. reward (past 10 ep.): -113.283, eps: 0.380 loss: 0.024
# Episode 100 - reward: -107.778, avg. reward (past 10 ep.): -135.286, eps: 0.369 loss: 0.069
# Episode 110 - reward: -0.224, avg. reward (past 10 ep.): -22.099, eps: 0.358 loss: 0.042
# Episode 120 - reward: -341.270, avg. reward (past 10 ep.): -64.573, eps: 0.348 loss: 0.884
# Episode 130 - reward: -61.065, avg. reward (past 10 ep.): -97.560, eps: 0.337 loss: 0.105
# Episode 140 - reward: -230.223, avg. reward (past 10 ep.): -78.133, eps: 0.327 loss: 0.476
# Episode 150 - reward: -232.698, avg. reward (past 10 ep.): -100.529, eps: 0.318 loss: 0.097
# Episode 160 - reward: -51.187, avg. reward (past 10 ep.): -73.857, eps: 0.308 loss: 0.340
# Episode 170 - reward: -58.022, avg. reward (past 10 ep.): -164.801, eps: 0.299 loss: 0.042
# Episode 180 - reward: 39.471, avg. reward (past 10 ep.): -134.082, eps: 0.290 loss: 1.031
# Episode 190 - reward: 81.976, avg. reward (past 10 ep.): -47.823, eps: 0.282 loss: 0.263
# Episode 200 - reward: -128.428, avg. reward (past 10 ep.): -128.163, eps: 0.273 loss: 0.032
# Episode 210 - reward: -160.756, avg. reward (past 10 ep.): -178.795, eps: 0.265 loss: 0.168
# Episode 220 - reward: -165.275, avg. reward (past 10 ep.): -104.624, eps: 0.257 loss: 0.048
# Episode 230 - reward: -104.863, avg. reward (past 10 ep.): -93.645, eps: 0.250 loss: 0.107
# Episode 240 - reward: -132.461, avg. reward (past 10 ep.): -88.699, eps: 0.242 loss: 0.027
# Episode 250 - reward: -66.131, avg. reward (past 10 ep.): -61.811, eps: 0.235 loss: 0.114
# Episode 260 - reward: -104.300, avg. reward (past 10 ep.): -30.239, eps: 0.228 loss: 0.053
# Episode 270 - reward: -22.376, avg. reward (past 10 ep.): -100.590, eps: 0.221 loss: 0.026
# Episode 280 - reward: -24.656, avg. reward (past 10 ep.): -108.624, eps: 0.215 loss: 0.038
# Episode 290 - reward: 95.901, avg. reward (past 10 ep.): -68.397, eps: 0.209 loss: 0.015
# Episode 300 - reward: -174.319, avg. reward (past 10 ep.): -126.059, eps: 0.202 loss: 0.052
# Episode 310 - reward: 118.543, avg. reward (past 10 ep.): -73.603, eps: 0.196 loss: 0.732
# Episode 320 - reward: -155.883, avg. reward (past 10 ep.): -118.995, eps: 0.191 loss: 0.039
# Episode 330 - reward: -126.652, avg. reward (past 10 ep.): -93.385, eps: 0.185 loss: 0.035
# Episode 340 - reward: -213.228, avg. reward (past 10 ep.): -127.070, eps: 0.179 loss: 0.091
# Episode 350 - reward: -83.121, avg. reward (past 10 ep.): -70.544, eps: 0.174 loss: 0.168
# Episode 360 - reward: -58.379, avg. reward (past 10 ep.): -101.688, eps: 0.169 loss: 0.119
# Episode 370 - reward: -43.448, avg. reward (past 10 ep.): -145.276, eps: 0.164 loss: 0.051
# Episode 380 - reward: -23.306, avg. reward (past 10 ep.): -141.260, eps: 0.159 loss: 0.177
# Episode 390 - reward: -257.263, avg. reward (past 10 ep.): -120.142, eps: 0.154 loss: 0.029
# Episode 400 - reward: -210.451, avg. reward (past 10 ep.): -100.176, eps: 0.150 loss: 0.031
# Episode 410 - reward: 87.630, avg. reward (past 10 ep.): -106.335, eps: 0.145 loss: 0.049
# Episode 420 - reward: 12.687, avg. reward (past 10 ep.): -52.249, eps: 0.141 loss: 0.042
# Episode 430 - reward: -217.719, avg. reward (past 10 ep.): -163.076, eps: 0.137 loss: 0.040
# Episode 440 - reward: -216.113, avg. reward (past 10 ep.): -187.240, eps: 0.133 loss: 0.032
# Episode 450 - reward: -385.191, avg. reward (past 10 ep.): -45.680, eps: 0.129 loss: 0.381
# Episode 460 - reward: 168.895, avg. reward (past 10 ep.): -67.360, eps: 0.125 loss: 0.205
# Episode 470 - reward: -210.264, avg. reward (past 10 ep.): -55.592, eps: 0.121 loss: 0.104
# Episode 480 - reward: 202.508, avg. reward (past 10 ep.): -110.361, eps: 0.118 loss: 0.057
# Episode 490 - reward: 99.220, avg. reward (past 10 ep.): -55.567, eps: 0.114 loss: 0.035
# Episode 500 - reward: 248.666, avg. reward (past 10 ep.): -41.252, eps: 0.111 loss: 0.144
# Episode 510 - reward: -166.751, avg. reward (past 10 ep.): -103.692, eps: 0.108 loss: 0.039
# Episode 520 - reward: -124.214, avg. reward (past 10 ep.): 21.989, eps: 0.105 loss: 0.163
# Episode 530 - reward: -64.222, avg. reward (past 10 ep.): -120.567, eps: 0.101 loss: 0.057
# Episode 540 - reward: -86.153, avg. reward (past 10 ep.): -53.951, eps: 0.098 loss: 0.066
# Episode 550 - reward: 179.118, avg. reward (past 10 ep.): 30.147, eps: 0.095 loss: 0.029
# Episode 560 - reward: -147.075, avg. reward (past 10 ep.): 50.144, eps: 0.093 loss: 0.044
# Episode 570 - reward: 213.033, avg. reward (past 10 ep.): -74.799, eps: 0.090 loss: 0.078
# Episode 580 - reward: 227.587, avg. reward (past 10 ep.): 39.748, eps: 0.087 loss: 0.044
# Episode 590 - reward: -149.908, avg. reward (past 10 ep.): -7.148, eps: 0.085 loss: 0.048
# Episode 600 - reward: 130.430, avg. reward (past 10 ep.): 50.481, eps: 0.082 loss: 0.155
# Episode 610 - reward: -206.686, avg. reward (past 10 ep.): -10.320, eps: 0.080 loss: 0.053
# Episode 620 - reward: 249.092, avg. reward (past 10 ep.): -28.482, eps: 0.077 loss: 0.046
# Episode 630 - reward: 303.982, avg. reward (past 10 ep.): 37.989, eps: 0.075 loss: 0.082
# Episode 640 - reward: -195.388, avg. reward (past 10 ep.): 33.006, eps: 0.073 loss: 0.024
# Episode 650 - reward: -180.415, avg. reward (past 10 ep.): -83.481, eps: 0.071 loss: 0.074
# Episode 660 - reward: 245.641, avg. reward (past 10 ep.): 21.973, eps: 0.069 loss: 0.058
# Episode 670 - reward: -152.931, avg. reward (past 10 ep.): -60.629, eps: 0.067 loss: 0.035
# Episode 680 - reward: 7.078, avg. reward (past 10 ep.): 5.438, eps: 0.065 loss: 0.039
# Episode 690 - reward: -99.118, avg. reward (past 10 ep.): -14.282, eps: 0.063 loss: 0.081
# Episode 700 - reward: 192.755, avg. reward (past 10 ep.): 33.599, eps: 0.061 loss: 0.031
# Episode 710 - reward: 9.634, avg. reward (past 10 ep.): 103.385, eps: 0.059 loss: 0.167
# Episode 720 - reward: 251.959, avg. reward (past 10 ep.): 155.024, eps: 0.057 loss: 0.362
# Episode 730 - reward: 56.632, avg. reward (past 10 ep.): -2.656, eps: 0.056 loss: 0.039
# Episode 740 - reward: 255.263, avg. reward (past 10 ep.): 123.166, eps: 0.054 loss: 0.062
# Episode 750 - reward: 186.608, avg. reward (past 10 ep.): 80.759, eps: 0.052 loss: 0.109
# Episode 760 - reward: 244.734, avg. reward (past 10 ep.): 159.252, eps: 0.051 loss: 0.092
# Episode 770 - reward: 201.459, avg. reward (past 10 ep.): 101.399, eps: 0.049 loss: 0.055
# Episode 780 - reward: 134.390, avg. reward (past 10 ep.): 127.468, eps: 0.048 loss: 0.043
# Episode 790 - reward: -45.918, avg. reward (past 10 ep.): 151.358, eps: 0.046 loss: 0.057
# Episode 800 - reward: 213.107, avg. reward (past 10 ep.): 144.478, eps: 0.045 loss: 0.059
# Episode 810 - reward: 264.361, avg. reward (past 10 ep.): 178.567, eps: 0.044 loss: 0.048
# Episode 820 - reward: 18.127, avg. reward (past 10 ep.): 164.622, eps: 0.042 loss: 0.062
# Episode 830 - reward: 217.608, avg. reward (past 10 ep.): 200.505, eps: 0.041 loss: 0.042
# Episode 840 - reward: -133.271, avg. reward (past 10 ep.): 85.054, eps: 0.040 loss: 0.065
# Episode 850 - reward: 15.924, avg. reward (past 10 ep.): 94.346, eps: 0.039 loss: 0.022
# Episode 860 - reward: 265.945, avg. reward (past 10 ep.): 150.530, eps: 0.038 loss: 1.620
# Episode 870 - reward: -41.896, avg. reward (past 10 ep.): 153.371, eps: 0.037 loss: 0.032
# Episode 880 - reward: 242.246, avg. reward (past 10 ep.): 161.739, eps: 0.035 loss: 0.024
# Episode 890 - reward: 272.273, avg. reward (past 10 ep.): 161.183, eps: 0.034 loss: 0.023
# Episode 900 - reward: 14.770, avg. reward (past 10 ep.): 136.173, eps: 0.033 loss: 0.043
# Episode 910 - reward: 237.771, avg. reward (past 10 ep.): 205.240, eps: 0.032 loss: 0.075
# Episode 920 - reward: 11.349, avg. reward (past 10 ep.): 55.161, eps: 0.031 loss: 0.098
# Episode 930 - reward: 217.820, avg. reward (past 10 ep.): 78.421, eps: 0.030 loss: 0.027
# Episode 940 - reward: 191.365, avg. reward (past 10 ep.): 110.194, eps: 0.030 loss: 0.106
# Episode 950 - reward: 185.567, avg. reward (past 10 ep.): 148.789, eps: 0.029 loss: 0.035
# Episode 960 - reward: 91.934, avg. reward (past 10 ep.): 138.124, eps: 0.028 loss: 0.056
# Episode 970 - reward: 0.382, avg. reward (past 10 ep.): 147.086, eps: 0.027 loss: 0.047
# Episode 980 - reward: 139.410, avg. reward (past 10 ep.): 114.662, eps: 0.026 loss: 0.159
# Episode 990 - reward: 171.251, avg. reward (past 10 ep.): 60.115, eps: 0.025 loss: 0.038
# Episode 1000 - reward: 206.970, avg. reward (past 10 ep.): 70.145, eps: 0.025 loss: 0.068
# Episode 1010 - reward: -152.588, avg. reward (past 10 ep.): 90.863, eps: 0.024 loss: 0.054
# Episode 1020 - reward: -190.909, avg. reward (past 10 ep.): 65.719, eps: 0.023 loss: 0.047
# Episode 1030 - reward: 268.620, avg. reward (past 10 ep.): 179.890, eps: 0.023 loss: 0.042
# Episode 1040 - reward: 219.893, avg. reward (past 10 ep.): 36.351, eps: 0.022 loss: 0.088
# Episode 1050 - reward: 213.669, avg. reward (past 10 ep.): 192.542, eps: 0.021 loss: 0.045
# Episode 1060 - reward: -48.254, avg. reward (past 10 ep.): 87.856, eps: 0.021 loss: 0.031
# Episode 1070 - reward: 196.230, avg. reward (past 10 ep.): 92.606, eps: 0.020 loss: 0.055
# Episode 1080 - reward: 180.423, avg. reward (past 10 ep.): 150.230, eps: 0.019 loss: 0.018
# Episode 1090 - reward: 225.326, avg. reward (past 10 ep.): 143.072, eps: 0.019 loss: 0.023
# Episode 1100 - reward: 259.338, avg. reward (past 10 ep.): 161.095, eps: 0.018 loss: 0.059
# Episode 1110 - reward: 179.769, avg. reward (past 10 ep.): 197.092, eps: 0.018 loss: 0.045
# Episode 1120 - reward: -57.532, avg. reward (past 10 ep.): 129.974, eps: 0.017 loss: 0.023
# Episode 1130 - reward: 243.830, avg. reward (past 10 ep.): 71.847, eps: 0.017 loss: 1.297
# Episode 1140 - reward: 287.163, avg. reward (past 10 ep.): 188.613, eps: 0.016 loss: 1.143
# Episode 1150 - reward: 11.973, avg. reward (past 10 ep.): 165.661, eps: 0.016 loss: 0.753
# Episode 1160 - reward: -102.846, avg. reward (past 10 ep.): 102.313, eps: 0.015 loss: 0.036
# Episode 1170 - reward: -10.170, avg. reward (past 10 ep.): 186.868, eps: 0.015 loss: 0.045
# Episode 1180 - reward: -17.892, avg. reward (past 10 ep.): 131.736, eps: 0.014 loss: 0.060
# Episode 1190 - reward: 247.126, avg. reward (past 10 ep.): 208.511, eps: 0.014 loss: 0.029
# Episode 1200 - reward: 254.372, avg. reward (past 10 ep.): 209.503, eps: 0.014 loss: 0.046
# Episode 1210 - reward: 262.723, avg. reward (past 10 ep.): 192.245, eps: 0.013 loss: 0.023
# Episode 1220 - reward: -2.019, avg. reward (past 10 ep.): 186.615, eps: 0.013 loss: 0.081
# Episode 1230 - reward: 249.802, avg. reward (past 10 ep.): 226.459, eps: 0.012 loss: 0.134
# Episode 1240 - reward: 275.463, avg. reward (past 10 ep.): 191.453, eps: 0.012 loss: 0.033
# Episode 1250 - reward: 223.288, avg. reward (past 10 ep.): 188.309, eps: 0.012 loss: 0.039
# Episode 1260 - reward: 253.612, avg. reward (past 10 ep.): 199.761, eps: 0.011 loss: 0.233
# Episode 1270 - reward: 240.788, avg. reward (past 10 ep.): 171.700, eps: 0.011 loss: 0.064
# Episode 1280 - reward: 267.421, avg. reward (past 10 ep.): 253.266, eps: 0.011 loss: 0.032
# Episode 1290 - reward: 219.205, avg. reward (past 10 ep.): 178.663, eps: 0.010 loss: 0.039
# Episode 1300 - reward: -53.231, avg. reward (past 10 ep.): 194.261, eps: 0.010 loss: 0.036
# Episode 1310 - reward: 271.484, avg. reward (past 10 ep.): 220.291, eps: 0.010 loss: 0.021
# Episode 1320 - reward: 269.317, avg. reward (past 10 ep.): 250.900, eps: 0.009 loss: 0.059
# Episode 1330 - reward: 182.576, avg. reward (past 10 ep.): 182.468, eps: 0.009 loss: 0.037
# Episode 1340 - reward: 21.856, avg. reward (past 10 ep.): 139.202, eps: 0.009 loss: 0.106
# Episode 1350 - reward: 12.754, avg. reward (past 10 ep.): 173.349, eps: 0.009 loss: 0.051
# Episode 1360 - reward: 261.110, avg. reward (past 10 ep.): 167.494, eps: 0.008 loss: 0.064
# Episode 1370 - reward: 307.895, avg. reward (past 10 ep.): 152.743, eps: 0.008 loss: 0.080
# Episode 1380 - reward: 245.374, avg. reward (past 10 ep.): 264.899, eps: 0.008 loss: 0.029
# Episode 1390 - reward: 165.536, avg. reward (past 10 ep.): 201.369, eps: 0.008 loss: 0.024
# Episode 1400 - reward: 246.838, avg. reward (past 10 ep.): 244.344, eps: 0.007 loss: 0.860
# Episode 1410 - reward: 244.665, avg. reward (past 10 ep.): 196.290, eps: 0.007 loss: 0.079
# Episode 1420 - reward: 289.259, avg. reward (past 10 ep.): 246.172, eps: 0.007 loss: 0.068
# Episode 1430 - reward: 246.445, avg. reward (past 10 ep.): 177.994, eps: 0.007 loss: 0.041
# Episode 1440 - reward: 232.700, avg. reward (past 10 ep.): 221.001, eps: 0.007 loss: 0.039
# Episode 1450 - reward: 247.823, avg. reward (past 10 ep.): 219.674, eps: 0.006 loss: 0.034
# Episode 1460 - reward: 218.944, avg. reward (past 10 ep.): 242.797, eps: 0.006 loss: 0.062
# Episode 1470 - reward: 275.939, avg. reward (past 10 ep.): 255.171, eps: 0.006 loss: 0.103
# Episode 1480 - reward: 253.672, avg. reward (past 10 ep.): 244.383, eps: 0.006 loss: 0.054
# Episode 1490 - reward: 240.934, avg. reward (past 10 ep.): 198.473, eps: 0.006 loss: 0.048
# Episode 1500 - reward: 288.704, avg. reward (past 10 ep.): 228.875, eps: 0.006 loss: 0.055
# Episode 1510 - reward: 259.011, avg. reward (past 10 ep.): 209.683, eps: 0.005 loss: 0.834
# Episode 1520 - reward: 255.492, avg. reward (past 10 ep.): 208.245, eps: 0.005 loss: 0.072
# Episode 1530 - reward: 234.357, avg. reward (past 10 ep.): 169.460, eps: 0.005 loss: 0.717
# Episode 1540 - reward: 18.994, avg. reward (past 10 ep.): 156.551, eps: 0.005 loss: 2.585
# Episode 1550 - reward: 261.868, avg. reward (past 10 ep.): 204.487, eps: 0.005 loss: 0.184
# Episode 1560 - reward: 289.798, avg. reward (past 10 ep.): 252.879, eps: 0.005 loss: 0.043
# Episode 1570 - reward: 213.065, avg. reward (past 10 ep.): 191.463, eps: 0.004 loss: 0.052
# Episode 1580 - reward: 239.639, avg. reward (past 10 ep.): 201.770, eps: 0.004 loss: 0.288
# Episode 1590 - reward: 35.518, avg. reward (past 10 ep.): 149.845, eps: 0.004 loss: 0.029
# Episode 1600 - reward: 280.639, avg. reward (past 10 ep.): 98.397, eps: 0.004 loss: 0.099
# Episode 1610 - reward: 225.629, avg. reward (past 10 ep.): 195.436, eps: 0.004 loss: 0.043
# Episode 1620 - reward: 239.394, avg. reward (past 10 ep.): 222.759, eps: 0.004 loss: 0.230
# Episode 1630 - reward: 8.902, avg. reward (past 10 ep.): 182.667, eps: 0.004 loss: 0.024
# Episode 1640 - reward: 211.163, avg. reward (past 10 ep.): 141.237, eps: 0.004 loss: 0.434
# Episode 1650 - reward: 272.532, avg. reward (past 10 ep.): 189.012, eps: 0.004 loss: 0.024
# Episode 1660 - reward: 264.851, avg. reward (past 10 ep.): 153.111, eps: 0.003 loss: 0.025
# Episode 1670 - reward: 287.955, avg. reward (past 10 ep.): 210.403, eps: 0.003 loss: 0.359
# Episode 1680 - reward: 180.379, avg. reward (past 10 ep.): 187.391, eps: 0.003 loss: 0.060
# Episode 1690 - reward: 255.002, avg. reward (past 10 ep.): 265.885, eps: 0.003 loss: 0.040
# Episode 1700 - reward: 206.789, avg. reward (past 10 ep.): 258.590, eps: 0.003 loss: 0.033
# Episode 1710 - reward: 240.679, avg. reward (past 10 ep.): 169.427, eps: 0.003 loss: 0.051
# Episode 1720 - reward: 223.251, avg. reward (past 10 ep.): 244.174, eps: 0.003 loss: 0.028
# Episode 1730 - reward: 279.250, avg. reward (past 10 ep.): 250.878, eps: 0.003 loss: 0.047
# Episode 1740 - reward: 270.806, avg. reward (past 10 ep.): 209.886, eps: 0.003 loss: 0.462
# Episode 1750 - reward: 222.316, avg. reward (past 10 ep.): 213.222, eps: 0.003 loss: 0.041
# Episode 1760 - reward: 50.578, avg. reward (past 10 ep.): 122.582, eps: 0.003 loss: 0.027
# Episode 1770 - reward: -1.690, avg. reward (past 10 ep.): 154.779, eps: 0.002 loss: 0.033
# Episode 1780 - reward: 218.756, avg. reward (past 10 ep.): 194.196, eps: 0.002 loss: 0.135
# Episode 1790 - reward: 239.004, avg. reward (past 10 ep.): 157.194, eps: 0.002 loss: 0.457
# Episode 1800 - reward: 270.081, avg. reward (past 10 ep.): 199.418, eps: 0.002 loss: 0.638
# Episode 1810 - reward: 215.896, avg. reward (past 10 ep.): 183.372, eps: 0.002 loss: 0.023
# Episode 1820 - reward: 232.019, avg. reward (past 10 ep.): 180.775, eps: 0.002 loss: 0.046
# Episode 1830 - reward: 19.584, avg. reward (past 10 ep.): 218.260, eps: 0.002 loss: 0.049
# Episode 1840 - reward: 216.020, avg. reward (past 10 ep.): 162.035, eps: 0.002 loss: 0.039
# Episode 1850 - reward: 237.421, avg. reward (past 10 ep.): 112.342, eps: 0.002 loss: 0.017
# Episode 1860 - reward: 289.210, avg. reward (past 10 ep.): 145.689, eps: 0.002 loss: 0.063
# Episode 1870 - reward: 277.474, avg. reward (past 10 ep.): 239.902, eps: 0.002 loss: 0.025
# Episode 1880 - reward: 245.841, avg. reward (past 10 ep.): 185.568, eps: 0.002 loss: 0.043
# Episode 1890 - reward: 235.953, avg. reward (past 10 ep.): 173.780, eps: 0.002 loss: 0.053
# Episode 1900 - reward: 231.815, avg. reward (past 10 ep.): 193.040, eps: 0.002 loss: 0.689
# Episode 1910 - reward: 272.888, avg. reward (past 10 ep.): 187.315, eps: 0.002 loss: 0.081
# Episode 1920 - reward: 33.497, avg. reward (past 10 ep.): 185.985, eps: 0.002 loss: 0.059
# Episode 1930 - reward: 279.567, avg. reward (past 10 ep.): 228.716, eps: 0.002 loss: 2.237
# Episode 1940 - reward: 270.471, avg. reward (past 10 ep.): 220.460, eps: 0.001 loss: 0.031
# Episode 1950 - reward: 211.025, avg. reward (past 10 ep.): 163.666, eps: 0.001 loss: 0.024
# Episode 1960 - reward: -157.830, avg. reward (past 10 ep.): 161.702, eps: 0.001 loss: 0.158
# Episode 1970 - reward: 243.801, avg. reward (past 10 ep.): 173.251, eps: 0.001 loss: 0.156
# Episode 1980 - reward: -9.447, avg. reward (past 10 ep.): 200.225, eps: 0.001 loss: 0.054
# Episode 1990 - reward: 266.089, avg. reward (past 10 ep.): 202.687, eps: 0.001 loss: 0.024
# Complete

# %%
plt.plot(rewards_history, '-')
# add 100 episode moving average
avg_rewards_history = np.convolve(rewards_history, np.ones((100,))/100, mode='valid')
plt.plot(avg_rewards_history, '-')
plt.title('Rewards')
plt.show()
